# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %%
# Exceptions in file handling
def read_safely(path):
  error = None
  try:
    con_df = pd.read_csv(path,encoding = "ISO-8859-1")
    return con_df
  except FileNotFoundError as err:
    print("File %s does not exist. Try again." % path)

# %%
def clean_df(df, date_column):
    df['count']=1
    df[date_column] = pd.to_datetime(df[date_column])
    df['date_minus_time'] = df[date_column].apply( lambda df :datetime.datetime(year=df.year, month=df.month, day=df.day))
    df.set_index(df["date_minus_time"],inplace=True)
    
    week_counts= df['count'].resample('W', how='sum')
    week_counts = week_counts.fillna(0)
    df_by_week =  pd.DataFrame({date_column:week_counts.index, 'count':week_counts.values})
    return df_by_week

# %%
def get_sent_receive_invites(df, direction_column):
    invites_sent = df[df[direction_column] == 'OUTGOING']
    invites_received = df[df[direction_column] == 'INCOMING']
    return invites_sent, invites_received

# %%
def plot(df, x,y, xlabel, ylabel, title, fig_size, fig_color):
    fig,ax= plt.subplots(nrows=1)
    ax.plot(df[x],df[y], color = fig_color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    fig.set_size_inches(fig_size)
    return

# %%
def import_recruiters_contacts(path):
    contacts_df = read_safely('./connections.csv')
    words = ['Recruiter', 'Talent', 'Sourcer', 'Recruiting']
    contacts_df['Position'] = contacts_df['Position'].dropna().apply(lambda x: 'Recruiter' if 
                                                   (any(word in x for word in words)) else x,1)
    recruiters_df = contacts_df[contacts_df['Position'] == 'Recruiter']
    return recruiters_df

# %%
#Calling the functions 
con_df = read_safely('./connections.csv')
con_df_by_week = clean_df(con_df, 'Connected On')
invites_df = read_safely('Invitations.csv')
# Out:
# /Users/shraws/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   import sys

# %%
invites_sent, invites_received = get_sent_receive_invites(invites_df, 'Direction')

# %%
invites_sent_by_week = clean_df(invites_sent, 'Sent At')
invites_received_by_week = clean_df(invites_received, 'Sent At')
# Out:
# /Users/shraws/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/shraws/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/shraws/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/shraws/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   import sys

# %%
plot(con_df_by_week,'Connected On','count', 'Weeks', 
     'Number of Connections', 'Bar Plot - Number of Connections per week', 
     (15,5), '#8D6CAB')

# %%
plot(invites_sent_by_week,'Sent At','count', 'Weeks', 
     'Number of Invites', 'Bar Plot - Number of Invites Sent per week', 
     (15,5), '#8D6CAB')

# %%
plot(invites_received_by_week,'Sent At','count', 'Weeks', 
     'Number of Invites', 'Bar Plot - Number of Invites Sent per week', 
     (15,5), '#8D6CAB')

# %%
import_recruiters_contacts('Connections.csv')
# Out:
#      First Name                  Last Name                    Email Address  \
# 1        Tracie                    Connors              tracieco@lab126.com
# 2        Isabel                     Sarkis               isarkis@nvidia.com
# 3          Owen                      Byron                 jobscout@att.net
# 5          Cory                  Simmonsen                   corysim@me.com
# 6       Hermann                     Kepfer                Hkepfer@gmail.com
# 7          Beth              Kester-Warner              bethkw@extrahop.com
# 8         Nancy                     Newton           nancynew@microsoft.com
# 9         Missy     Roedersheimer Waggoner               mroeders@yahoo.com
# 11      Revathi                       Iyer     revathi.iyer@bloomenergy.com
# 12       Lorise                Best Morton               lorise16@gmail.com
# 14         John                      Hesse            john_hesse@intuit.com
# 15        Kathy                     Richie     realtechpeople@earthlink.net
# 18         Jeff                      Korte              jeffkorte@gmail.com
# 19           Jo                     Maxion            jo@eleven24search.com
# 22        Kevin                     Haynes             kevin.haynes@rms.com
# 24       Angela                 McLaughlin            angela.mc@climate.com
# 25        Jason                    Corbett             jcorbett@walmart.com
# 27         Paul                    Henneke       paul.henneke@bigswitch.com
# 28         Mike                   Brinkman     michael.brinkman@charter.com
# 29     Stefanie                 Matsudaira             stefma@microsoft.com
# 31         Mara                     Molina               mara@HashiCorp.com
# 33        Jacob                     Conway           jacob_conway@apple.com
# 35          Ken                     McKoon             Ken.McKoon@intel.com
# 37        Patty                      Olson              polson@covestic.com
# 40         Tami                   Cornwell           v-tacorn@microsoft.com
# 41       George                     Clarke        George.Clarke@sandisk.com
# 43     James M.                     Mooney        james.mooney1@comcast.net
# 44        Steve                     Greene        stephen.greene@huawei.com
# 45         Tony                Ciaramitaro             tonyc@corpsearch.com
# 48        Linda                      Marak     candidatewhisperer@gmail.com
# ...         ...                        ...                              ...
# 830        Matt                  Sheffield           mattshef@microsoft.com
# 831       Sonam                      Gupta      sonam.gupta@indigoslate.com
# 835    Abhineet              Singh Rajpoot              abhi.dyss@gmail.com
# 839      vishal                       Rana          vishal.askitc@gmail.com
# 852        Ryan                        Lee           ryan.lee@us.sogeti.com
# 862       Manju                   Upadhyay            mupadhyay@astreya.com
# 867      Gelila                     Asnake            gelilasnake@gmail.com
# 869       Emily                     Miller          emily.miller@oracle.com
# 875      Aditya                      Singh             aditya.vui@gmail.com
# 877       Jinse                  Sathyadas        jinse.s@aloisstaffing.com
# 891        Greg                      Grimm       ggrimm@vincentbenjamin.com
# 892      Gaurav                   Pancholi    gaurav.pancholi@collabera.com
# 903      Riddhi                       Shah        riddhi.shah@collabera.com
# 904       James                     Gannon          jamesgannonub@gmail.com
# 910        Asim                      Taher                     asimt@fb.com
# 914      Bianca                       Ruiz         bianca@joinhandshake.com
# 930    lawrence                        das         lawry.peter441@gmail.com
# 962     Rebecca                      Pence              yamachoma@gmail.com
# 970       Jason                    D'Souza       jason.dsouza1@rangtech.com
# 975       Pablo                      Ortiz     pablo.ortiz@sevensteprpo.com
# 977      Calvin  Liu-Navarro (ö÷¥ÀÀÏ_ä         cliunavarro@linkedin.com
# 981    Danielle                   Wimhurst  danielle.wimhurst@wunderman.com
# 984       Parag                     Mishra        parag.mishra.rt@gmail.com
# 986        Bret                   Cisneros        bretcisneros727@gmail.com
# 992       Simon                      Patel   simon@nextgendatasolutions.com
# 999       Bakul          Purabia [L.I.O.N]       bakul.purabia.rt@gmail.com
# 1022  Ramcharan                     Pillai      analytics.dcs4@rangtech.com
# 1030     Anjali                   Ambardar  anjali.manchanda@itdoseinfo.com
# 1034      Linda                      Stent               Linda.Stent@hp.com
# 1037  Joshua A.                  Leichtung              leichtung@gmail.com
#
#                                             Company   Position  \
# 1                                     Amazon Lab126  Recruiter
# 2                                            NVIDIA  Recruiter
# 3                                          Cohesity  Recruiter
# 5                                          Best Buy  Recruiter
# 6                                  RAND Corporation  Recruiter
# 7                                          ExtraHop  Recruiter
# 8                                         Microsoft  Recruiter
# 9                                   Apptio Software  Recruiter
# 11                                     Bloom Energy  Recruiter
# 12                                             Nike  Recruiter
# 14                                           Intuit  Recruiter
# 15                                               HP  Recruiter
# 18                                        Glassdoor  Recruiter
# 19                                  Eleven24 Search  Recruiter
# 22                                              RMS  Recruiter
# 24                          The Climate Corporation  Recruiter
# 25                         Walmart Global eCommerce  Recruiter
# 27                                         Dell EMC  Recruiter
# 28                                         Navisite  Recruiter
# 29                                        Microsoft  Recruiter
# 31                                        HashiCorp  Recruiter
# 33                                            Apple  Recruiter
# 35                                Intel Corporation  Recruiter
# 37                                         Covestic  Recruiter
# 40                                        Microsoft  Recruiter
# 41                                          SanDisk  Recruiter
# 43                                           Intuit  Recruiter
# 44                              Huawei Technologies  Recruiter
# 45        CorpSearch (Corporate Search Consultants)  Recruiter
# 48                              Purple Squirrel LLC  Recruiter
# ...                                             ...        ...
# 830                                       Microsoft  Recruiter
# 831                                    Indigo Slate  Recruiter
# 835                                    Confidential  Recruiter
# 839                               ASK IT Consulting  Recruiter
# 852                                          Sogeti  Recruiter
# 862                                         Astreya  Recruiter
# 867                                        Coursera  Recruiter
# 869                                          Oracle  Recruiter
# 875            TRG - Technology Resource Group Inc.  Recruiter
# 877                                       Collabera  Recruiter
# 891                                 VincentBenjamin  Recruiter
# 892                                 Collabera Inc.   Recruiter
# 903                                       Collabera  Recruiter
# 904                    Stealth Mode Startup Company  Recruiter
# 910                                        Facebook  Recruiter
# 914                       Handshake - Stryder Corp.  Recruiter
# 930                     Intelliswift Software, Inc.  Recruiter
# 962                                     CampusPoint  Recruiter
# 970                           Rang Technologies Inc  Recruiter
# 975                                         Equifax  Recruiter
# 977                                        LinkedIn  Recruiter
# 981                               Wunderman Seattle  Recruiter
# 984                           Rang Technologies Inc  Recruiter
# 986                                        Lumileds  Recruiter
# 992                          NextGen Data Solutions  Recruiter
# 999                           Rang Technologies Inc  Recruiter
# 1022                          Rang Technologies Inc  Recruiter
# 1030                          ITDOSE infosystem (p)  Recruiter
# 1034                                        HP Inc.  Recruiter
# 1037  Kim Finch Cook & Company Executive Recruiters  Recruiter
#
#            Connected On  Tags
# 1     4/12/17, 11:24 AM   NaN
# 2       6/5/17, 9:44 PM   NaN
# 3      5/22/17, 4:02 PM   NaN
# 5      1/30/17, 9:24 PM   NaN
# 6       4/6/16, 4:32 AM   NaN
# 7     10/26/16, 7:52 PM   NaN
# 8      5/18/17, 7:26 AM   NaN
# 9      3/30/17, 4:18 PM   NaN
# 11    5/15/17, 10:23 AM   NaN
# 12    4/18/17, 10:56 AM   NaN
# 14     4/12/17, 8:41 PM   NaN
# 15     4/12/17, 9:01 PM   NaN
# 18     3/13/17, 2:38 PM   NaN
# 19     4/11/17, 9:55 AM   NaN
# 22     5/16/17, 7:24 AM   NaN
# 24     5/25/17, 8:27 PM   NaN
# 25    4/18/17, 10:11 AM   NaN
# 27     4/11/17, 5:00 PM   NaN
# 28     3/20/17, 7:10 PM   NaN
# 29     1/30/17, 8:37 PM   NaN
# 31     9/11/17, 5:08 PM   NaN
# 33     4/11/17, 2:32 PM   NaN
# 35     4/25/17, 8:05 AM   NaN
# 37     7/1/17, 12:18 AM   NaN
# 40     1/30/17, 2:35 PM   NaN
# 41     4/13/17, 3:45 PM   NaN
# 43     4/13/17, 4:31 PM   NaN
# 44    4/11/17, 10:41 AM   NaN
# 45     5/11/17, 2:11 PM   NaN
# 48      3/1/17, 2:28 PM   NaN
# ...                 ...   ...
# 830     2/2/17, 7:09 PM   NaN
# 831    4/3/17, 11:24 AM   NaN
# 835    2/23/17, 8:17 AM   NaN
# 839   8/14/17, 11:05 AM   NaN
# 852    4/6/17, 10:58 AM   NaN
# 862   10/16/17, 2:02 PM   NaN
# 867   4/20/17, 10:01 AM   NaN
# 869    6/26/17, 6:34 AM   NaN
# 875   7/19/17, 11:14 AM   NaN
# 877   4/17/17, 11:17 AM   NaN
# 891     8/9/17, 2:57 PM   NaN
# 892    3/3/17, 11:59 AM   NaN
# 903    10/2/17, 9:32 AM   NaN
# 904     4/3/17, 6:08 PM   NaN
# 910    4/28/17, 9:42 PM   NaN
# 914     4/3/17, 8:06 PM   NaN
# 930    6/13/17, 2:24 AM   NaN
# 962    1/30/17, 4:18 PM   NaN
# 970   3/17/17, 10:50 AM   NaN
# 975    4/12/17, 7:24 AM   NaN
# 977   10/7/17, 11:13 PM   NaN
# 981     9/6/17, 1:31 PM   NaN
# 984    1/29/17, 9:25 PM   NaN
# 986   3/20/17, 10:02 AM   NaN
# 992   4/17/17, 11:40 AM   NaN
# 999    12/9/16, 7:36 PM   NaN
# 1022  2/20/17, 11:08 PM   NaN
# 1030    3/1/17, 9:07 AM   NaN
# 1034   4/24/17, 3:51 PM   NaN
# 1037  8/22/17, 10:04 PM   NaN
#
# [279 rows x 7 columns]
