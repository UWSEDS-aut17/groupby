# %%
import argparse
import arrow
import codecs
import datetime
import ics
import itertools
import pyparsing as pp
import re
import os
from collections import defaultdict
import io
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

import calendar
# %matplotlib inline


def _group(s, groups):
    """Group a string using regex groups.
  
    Args:
        s: the string to group
        groups: a list of tuples of (regex pattern, replacement string)
    Returns:
        the group for the string
    """
    for pattern, replacement in groups:
        if pattern.match(s):
            return replacement
    return s


def _total_hours(seconds):
    """Converts seconds to hours.
  
    Args:
        seconds: the total seconds
    Returns:
        the total hours as a float
    """
    return seconds / 3600.0


def _parse_regexes(regexes):
    """Parses regexes in the form of '/from/to/options'.
  
    Note: this doesn't handle regex patterns
  
    Args:
        regexes: a list of regex strings
    Returns:
        a list of (regex pattern, replacement string)
    """
    regexBNF = (pp.Literal('/').suppress() +
                pp.Word(pp.printables + ' \t\n\r', excludeChars='/') +
                pp.Literal('/').suppress() +
                pp.Word(pp.printables + ' \t\n\r', excludeChars='/') +
                pp.Optional(pp.Literal('/').suppress() +
                            pp.ZeroOrMore(pp.Literal('i') ^
                                          pp.Literal('L') ^
                                          pp.Literal('s') ^
                                          pp.Literal('u') ^
                                          pp.Literal('x'))) +
                pp.StringEnd())
    results = []
    for regex in regexes:
        try:
            parsed = regexBNF.parseString(regex)
        except pp.ParseException as e:
            print('Unable to parse regex {0}'.format(regex))
            raise e
        regex_str = parsed[0]
        replace_str = parsed[1]
        if len(parsed) > 2:
            regex_str = '(?{0}){1}'.format(''.join(parsed[2:]), regex_str)
        print('Replacing {0} with {1}'.format(regex_str, replace_str))
        results.append((re.compile(regex_str), replace_str))
    return results


def _process_calendar(calendar_file,
#                       start_date,
#                       end_date,
                      allday,
                      grouping_regex_strs):
    """Processes a calendar, grouping events by name.
  
    Args:
        calendar_file: the ics calendar file
        start_date: the starting date, or None
        end_date: the end date, or None
        allday: if true, includes all day events in processing
        grouping_regex_strs: regular expressions for grouping patterns
    """
    #print('Processing events from {0} to {1}'.format(start_date, end_date))
    print("Calendar file name", calendar_file)
    print("File type", calendar_file)
    #calendar_file = os.path.join('data', calendar_file)
    #cal_file = io.TextIOWrapper(io.open(calendar_file, encoding='iso-8859-1', mode='r'))
    #print(type(cal_file))
    #regexes = _parse_regexes(grouping_regex_strs)
    #calendar = ics.Calendar(cal_file)
    calendar = ics.Calendar(open(calendar_file).read())
    cal_df = pd.DataFrame(columns=['day','month','year','hour','event_name','duration'])
    groups = defaultdict(lambda: 0)
    total_seconds = 0
    i=0
    for event in calendar.events:
#         if not allday and event.all_day:
#             continue
#         if start_date and arrow.get(event.begin) < start_date:
#             continue
#         if end_date and arrow.get(event.end) > end_date:
#             continue
        #total_seconds += event.duration.total_seconds()
        #event_name = _group(event.name, regexes)
        #groups[event_name] += event.duration.total_seconds()
        start_date = arrow.get(event.begin)
        end_date =  arrow.get(event.end)
        cal_df.loc[i] = [start_date.datetime.day,start_date.datetime.month,start_date.datetime.year,
                         start_date.datetime.hour,
                         event.name,event.duration.total_seconds()]
        i+=1
    print(cal_df)
#     for name, duration in sorted(groups.items(),
#                                  key=lambda item: item[1],
#                                  reverse=True):
#         print('{0}: {1}'.format(name, _total_hours(duration)))
    return cal_df


def _valid_date(s):
    """Validates and converts a date as arrow-compatible.
  
    Args:
        s: the string argument
    Returns:
        an arrow date
    Raises:
        ArgumentTypeError: if the date is invalid
    """
    try:
        return arrow.get(s)
    except TypeError:
        msg = "Not a valid date: '{0}'.".format(s)
        raise argparse.ArgumentTypeError(msg)

# %%
calendar_file = 'shsher@uw.edu.ics'
allday= False
#grouping_regex_strs = "/.*meeting.*/Meetings/i"
cal_df = _process_calendar(calendar_file,
#                       start_date,
#                       end_date,
                      allday,
                      grouping_regex_strs)
# Out:
# Calendar file name shsher@uw.edu.ics
# File type shsher@uw.edu.ics
#     day month  year hour                                         event_name  \
# 0     1     1  2016    0                          aditya narayan's birthday
# 1    18     3  2016    0                                Sri Rama's birthday
# 2     1     4  2016    0         Anirban Chatterjee BITS (Paanu)'s birthday
# 3     3     5  2016    0                            Kevin Mathew's birthday
# 4     4     6  2016    0                          Nishank Shinde's birthday
# 5    21     6  2016    0                          Vipul Aggarwal's birthday
# 6    28     6  2016    0                   MASTER CHIEF JOHN 117's birthday
# 7    28     6  2016    0                                Mohit B.'s birthday
# 8     7     7  2016    0                      Shweta Mattoo Koul's birthday
# 9    12     7  2016    0                       Gokul Subramanian's birthday
# 10    6     8  2016    0                        K.Chandrasekaran's birthday
# 11   19     8  2016    0                       Brijesh Bharadwaj's birthday
# 12   15     9  2016    0                       Sankha Subhra ...'s birthday
# 13   20     9  2016   14                                        Unavailable
# 14    4    10  2016    0                           Swapnil Gupta's birthday
# 15    6    10  2016   13  Assignment Created - Topic Analysis #1: Inform...
# 16   12    10  2016    0                             Rohan Gupta's birthday
# 17   12    10  2016    0  Tomorrow: Cross-Sector Collaboration in Data S...
# 18   16    10  2016    0                          arjun varshney's birthday
# 19   17    10  2016   11  Shrawan, you just booked to participate in the...
# 20   17    10  2016   12                         Workshop RSVP Confirmation
# 21   19    10  2016   12  EVENT: Town Hall meetings for MSIM 1st year st...
# 22   20    10  2016   17                   UW InfoSession RSVP Confirmation
# 23   25    10  2016   11  Hacking the Academy, First Gen, Teaching Award...
# 24   27    10  2016   15                   Relevant talk on Thursday in CSE
# 25   28    10  2016   12                         Workshop RSVP Confirmation
# 26    1    11  2016    0  Assignment 4: Contingency Tables & Cross-Tabul...
# 27    2    11  2016   15  UW Data Science Seminar - Rob Axtell - Nov. 2,...
# 28    2    11  2016   15  UW Data Science Seminar - Rob Axtell - Nov. 2,...
# 29    3    11  2016   12  You're invited: Come meet the Technology & Soc...
# ..   ..   ...   ...  ...                                                ...
# 142  30    10  2017   19                              Capstone Team Meeting
# 143   2    11  2017    9  NDA AI Developer Call: Thurs. Nov. 2 9-10:30 A...
# 144   3    11  2017   15                                       Registration
# 145   7    11  2017    0                                 Global IoT DevFest
# 146   8    11  2017   10                    UW Capstone // PitchBook Onsite
# 147   9    11  2017   12                      Fix meeting time for Capstone
# 148  14    11  2017   13                                       Lunch Invite
# 149  16    11  2017   10  Interview with Redfin for Software Developer I...
# 150  28    11  2017   19                     TheHubTix.com Receipt (KDWWLJ)
# 151  30    11  2017   18  Amazon Alexa: Skill Development Workshops - Se...
# 152  30    11  2017   18  Amazon Alexa: Skill Development Workshops - Se...
# 153  12    12  2017   13                                  Tinder + Shrawan!
# 154  26    12  2017    0                              Siddhartha's birthday
# 155   1     1  2018    0                          aditya narayan's birthday
# 156   3     3  2018   20  Your Hamilton (Touring) Ticket Order 17-58027/SEA
# 157   1     4  2018    0         Anirban Chatterjee BITS (Paanu)'s birthday
# 158   3     5  2018    0                            Kevin Mathew's birthday
# 159  21     6  2018    0                          Vipul Aggarwal's birthday
# 160  28     6  2018    0                                Mohit B.'s birthday
# 161  28     6  2018    0                   MASTER CHIEF JOHN 117's birthday
# 162   7     7  2018    0                      Shweta Mattoo Koul's birthday
# 163  12     7  2018    0                       Gokul Subramanian's birthday
# 164   6     8  2018    0                        K.Chandrasekaran's birthday
# 165  19     8  2018    0                       Brijesh Bharadwaj's birthday
# 166  15     9  2018    0                       Sankha Subhra ...'s birthday
# 167   4    10  2018    0                           Swapnil Gupta's birthday
# 168  16    10  2018    0                          arjun varshney's birthday
# 169   3    12  2018    0                         surya choudhury's birthday
# 170   4    12  2018    0                         Nishant Bhaskar's birthday
# 171  26    12  2018    0                              Siddhartha's birthday
#
#      duration
# 0    172800.0
# 1    172800.0
# 2    172800.0
# 3    172800.0
# 4    172800.0
# 5    172800.0
# 6    172800.0
# 7    172800.0
# 8    172800.0
# 9    172800.0
# 10   172800.0
# 11   172800.0
# 12   172800.0
# 13     1800.0
# 14   172800.0
# 15     3600.0
# 16   172800.0
# 17   172800.0
# 18   172800.0
# 19     1800.0
# 20     3000.0
# 21     3600.0
# 22     3600.0
# 23     5400.0
# 24     3600.0
# 25     3000.0
# 26   172800.0
# 27     3600.0
# 28     3600.0
# 29     3000.0
# ..        ...
# 142    3600.0
# 143    5400.0
# 144     900.0
# 145  144000.0
# 146    3600.0
# 147     600.0
# 148    3600.0
# 149    3600.0
# 150    3600.0
# 151   10800.0
# 152   10800.0
# 153    3600.0
# 154  172800.0
# 155  172800.0
# 156    3600.0
# 157  172800.0
# 158  172800.0
# 159  172800.0
# 160  172800.0
# 161  172800.0
# 162  172800.0
# 163  172800.0
# 164  172800.0
# 165  172800.0
# 166  172800.0
# 167  172800.0
# 168  172800.0
# 169  172800.0
# 170  172800.0
# 171  172800.0
#
# [172 rows x 6 columns]

# %%
cal_df.head()
cal_df['minutes'] = cal_df['duration']/60
cal_df['hours'] = cal_df['duration']/3600

# %%
#remove birthdays and events longer than 1 day
cal_df = cal_df[~cal_df['event_name'].str.contains('birthday')]
cal_df = cal_df[(cal_df['hours']<24) & (cal_df['hours']>0)]

# %%
cal_df
# Out:
#     day month  year hour                                         event_name  \
# 13   20     9  2016   14                                        Unavailable
# 15    6    10  2016   13  Assignment Created - Topic Analysis #1: Inform...
# 19   17    10  2016   11  Shrawan, you just booked to participate in the...
# 20   17    10  2016   12                         Workshop RSVP Confirmation
# 21   19    10  2016   12  EVENT: Town Hall meetings for MSIM 1st year st...
# 22   20    10  2016   17                   UW InfoSession RSVP Confirmation
# 23   25    10  2016   11  Hacking the Academy, First Gen, Teaching Award...
# 24   27    10  2016   15                   Relevant talk on Thursday in CSE
# 25   28    10  2016   12                         Workshop RSVP Confirmation
# 27    2    11  2016   15  UW Data Science Seminar - Rob Axtell - Nov. 2,...
# 28    2    11  2016   15  UW Data Science Seminar - Rob Axtell - Nov. 2,...
# 29    3    11  2016   12  You're invited: Come meet the Technology & Soc...
# 32    4    11  2016   15                                      Week 6 Digest
# 35    7    11  2016   15  UWEE Lytle Lectures 2016, Prof. David Donoho (...
# 37    7    11  2016   17                                        Happy Hours
# 38    7    11  2016   18                   UW InfoSession RSVP Confirmation
# 39    8    11  2016   10  UWEE Lytle Lectures 2016, Prof. David Donoho (...
# 42    8    11  2016   17                   UW InfoSession RSVP Confirmation
# 43    9    11  2016   14  Data Science Studies Working Group meeting: We...
# 44    9    11  2016   18  CAREER: Newsletter, 11.3.2016, Job Offers: Ask...
# 45   10    11  2016   12    EVENT: Join us for lunch to celebrate Veterans!
# 48   10    11  2016   15  UW CSE Distinguished Lecture! / Thursday, Nove...
# 52   16    11  2016   15  UW Data Science Seminar - Matthew J. Salganik ...
# 55   22    11  2016   12  Mark this on your calendar! Invitation to Open...
# 62    2    12  2016   15  MathAcrossCampus talk this Friday, Dec. 2, at ...
# 63    2    12  2016   15  Math Across Campus talk on bike sharing, Fri, ...
# 65    2    12  2016   19       La La Land 12/5 Screening Confirmation Email
# 68    5    12  2016   16                                   research ppt 570
# 69    5    12  2016   18               machines who learn linear regression
# 70    5    12  2016   18  Physical Computing Showcase: Dec 5, 6:00 -- 7:...
# ..   ..   ...   ...  ...                                                ...
# 115  23     5  2017   19                         Data Vis - Working Session
# 116  26     5  2017   19  561 - Peer projects review assignment - Review...
# 117   3     6  2017   10                       Vis Report - Working Session
# 119   4     6  2017    9                     Vis Sync - finalize and submit
# 120   4     6  2017   21                          561 final project sync up
# 121   6     6  2017   14                                        Amazon Test
# 123  25     6  2017   17                        Finish IMT 590 Assignment 1
# 126   5     7  2017   16               Amazon SDE Internship Overview - 7/5
# 129  27     7  2017   16  NDA Student Ambassador Call - Student Ambassad...
# 132  24     8  2017   19        Booking Confirmation for Cinerama - WF5JF98
# 134  26     9  2017    8         Welcome to Amazon! New Hire Info. Enclosed
# 135   4    10  2017   12                                            CSE 583
# 136   6    10  2017   17                                               DS 3
# 137  16    10  2017    8          Student Ambassador Technical Office Hours
# 138  23    10  2017   18                  MSIM Capstone Information Session
# 139  26    10  2017   18  Amazon Alexa: Skill Development Workshops - Se...
# 140  28    10  2017   15  Free Interview Practice: Coding, Algorithms an...
# 141  30    10  2017   12                                  Tinder + Shrawan!
# 142  30    10  2017   19                              Capstone Team Meeting
# 143   2    11  2017    9  NDA AI Developer Call: Thurs. Nov. 2 9-10:30 A...
# 144   3    11  2017   15                                       Registration
# 146   8    11  2017   10                    UW Capstone // PitchBook Onsite
# 147   9    11  2017   12                      Fix meeting time for Capstone
# 148  14    11  2017   13                                       Lunch Invite
# 149  16    11  2017   10  Interview with Redfin for Software Developer I...
# 150  28    11  2017   19                     TheHubTix.com Receipt (KDWWLJ)
# 151  30    11  2017   18  Amazon Alexa: Skill Development Workshops - Se...
# 152  30    11  2017   18  Amazon Alexa: Skill Development Workshops - Se...
# 153  12    12  2017   13                                  Tinder + Shrawan!
# 156   3     3  2018   20  Your Hamilton (Touring) Ticket Order 17-58027/SEA
#
#      duration  minutes     hours
# 13     1800.0     30.0  0.500000
# 15     3600.0     60.0  1.000000
# 19     1800.0     30.0  0.500000
# 20     3000.0     50.0  0.833333
# 21     3600.0     60.0  1.000000
# 22     3600.0     60.0  1.000000
# 23     5400.0     90.0  1.500000
# 24     3600.0     60.0  1.000000
# 25     3000.0     50.0  0.833333
# 27     3600.0     60.0  1.000000
# 28     3600.0     60.0  1.000000
# 29     3000.0     50.0  0.833333
# 32     7200.0    120.0  2.000000
# 35     3600.0     60.0  1.000000
# 37     9000.0    150.0  2.500000
# 38     3600.0     60.0  1.000000
# 39     3600.0     60.0  1.000000
# 42     3600.0     60.0  1.000000
# 43     3600.0     60.0  1.000000
# 44     5400.0     90.0  1.500000
# 45     3600.0     60.0  1.000000
# 48     3600.0     60.0  1.000000
# 52     3600.0     60.0  1.000000
# 55     3600.0     60.0  1.000000
# 62     3600.0     60.0  1.000000
# 63     3600.0     60.0  1.000000
# 65     3600.0     60.0  1.000000
# 68     5400.0     90.0  1.500000
# 69     3600.0     60.0  1.000000
# 70     5400.0     90.0  1.500000
# ..        ...      ...       ...
# 115    7200.0    120.0  2.000000
# 116    5400.0     90.0  1.500000
# 117   14400.0    240.0  4.000000
# 119    3600.0     60.0  1.000000
# 120    3600.0     60.0  1.000000
# 121   10800.0    180.0  3.000000
# 123    6300.0    105.0  1.750000
# 126    3600.0     60.0  1.000000
# 129    5400.0     90.0  1.500000
# 132    3600.0     60.0  1.000000
# 134    3600.0     60.0  1.000000
# 135    4800.0     80.0  1.333333
# 136   10200.0    170.0  2.833333
# 137    3600.0     60.0  1.000000
# 138    3600.0     60.0  1.000000
# 139   10800.0    180.0  3.000000
# 140    7200.0    120.0  2.000000
# 141    3600.0     60.0  1.000000
# 142    3600.0     60.0  1.000000
# 143    5400.0     90.0  1.500000
# 144     900.0     15.0  0.250000
# 146    3600.0     60.0  1.000000
# 147     600.0     10.0  0.166667
# 148    3600.0     60.0  1.000000
# 149    3600.0     60.0  1.000000
# 150    3600.0     60.0  1.000000
# 151   10800.0    180.0  3.000000
# 152   10800.0    180.0  3.000000
# 153    3600.0     60.0  1.000000
# 156    3600.0     60.0  1.000000
#
# [96 rows x 8 columns]

# %%
cal_df['count']=1

# %%
cal_min = cal_df.groupby(['event_name'],as_index=False)['event_name','count','minutes'].sum()

# %%
cal_min.sort_values('minutes',ascending=False)
# Out:
#                                            event_name  count  minutes
# 8   Amazon Alexa: Skill Development Workshops - Se...      3    540.0
# 23                         Data Vis - Working Session      2    510.0
# 76                    Visualisation - Working Session      1    480.0
# 29                                   Flight to Newark      1    311.0
# 40                  Interview with Prime 8 Consulting      2    255.0
# 72                       Vis Report - Working Session      1    240.0
# 1                                    550 Policy Class      2    190.0
# 53  Paseo + GrubHub Launch Party: A Combo So Tasty...      1    180.0
# 67                   UW InfoSession RSVP Confirmation      3    180.0
# 22                  Data Science in Thirty Minutes #3      1    180.0
# 39                                    Internship Fair      1    180.0
# 10                                        Amazon Test      1    180.0
# 37  Intel AI Deep Learning Technical Seminar at Un...      1    180.0
# 18                                               DS 3      1    170.0
# 34                                        Happy Hours      1    150.0
# 66                                       UW Film Club      1    150.0
# 30                                  Flight to Seattle      1    129.0
# 68  UWEE Lytle Lectures 2016, Prof. David Donoho (...      2    120.0
# 77                                      Week 6 Digest      1    120.0
# 32  Free Interview Practice: Coding, Algorithms an...      1    120.0
# 65  UW Data Science Seminar - Rob Axtell - Nov. 2,...      2    120.0
# 45                              MWL Foundational Math      1    120.0
# 61                                  Tinder + Shrawan!      2    120.0
# 36                                           INFX 598      1    110.0
# 19                                                DS2      1    110.0
# 5                                             573 DS1      1    110.0
# 70                                         VIZ DESIGN      1    110.0
# 27                        Finish IMT 590 Assignment 1      1    105.0
# 79                         Workshop RSVP Confirmation      2    100.0
# 55  Physical Computing Showcase: Dec 5, 6:00 -- 7:...      1     90.0
# ..                                                ...    ...      ...
# 26  EVENT: Town Hall meetings for MSIM 1st year st...      1     60.0
# 25    EVENT: Join us for lunch to celebrate Veterans!      1     60.0
# 3                              561 Project discussion      1     60.0
# 4                           561 final project sync up      1     60.0
# 6                                             576 SNA      1     60.0
# 9                Amazon SDE Internship Overview - 7/5      1     60.0
# 11  Assignment Created - Topic Analysis #1: Inform...      1     60.0
# 12        Booking Confirmation for Cinerama - WF5JF98      1     60.0
# 16                              Capstone Team Meeting      1     60.0
# 21  Data Science Studies Working Group meeting: We...      1     60.0
# 24                             Data science interview      1     60.0
# 42       La La Land 12/5 Screening Confirmation Email      1     60.0
# 46                                       MWL Workshop      1     60.0
# 48  Math Across Campus talk on bike sharing, Fri, ...      1     60.0
# 50                                  Meeting with Joel      1     60.0
# 41  Interview with Redfin for Software Developer I...      1     60.0
# 43                                       Lunch Invite      1     60.0
# 49  MathAcrossCampus talk this Friday, Dec. 2, at ...      1     60.0
# 44                  MSIM Capstone Information Session      1     60.0
# 47  Mark this on your calendar! Invitation to Open...      1     60.0
# 81  You're invited: Come meet the Technology & Soc...      1     50.0
# 58  Shrawan, you just booked to participate in the...      1     30.0
# 7                                             580 PPt      1     30.0
# 35                          INFX 572 Grader Interview      1     30.0
# 38  Intel Student Ambassdaor Interview - Niven & S...      1     30.0
# 69                                        Unavailable      1     30.0
# 54                                  Pay Discover Bill      1     30.0
# 17                               Costco IS internship      1     25.0
# 56                                       Registration      1     15.0
# 28                      Fix meeting time for Capstone      1     10.0
#
# [85 rows x 3 columns]

# %%
cal_df.head()
# Out:
#    day month  year hour                                         event_name  \
# 13  20     9  2016   14                                        Unavailable
# 15   6    10  2016   13  Assignment Created - Topic Analysis #1: Inform...
# 19  17    10  2016   11  Shrawan, you just booked to participate in the...
# 20  17    10  2016   12                         Workshop RSVP Confirmation
# 21  19    10  2016   12  EVENT: Town Hall meetings for MSIM 1st year st...
#
#     duration  minutes     hours  count
# 13    1800.0     30.0  0.500000      1
# 15    3600.0     60.0  1.000000      1
# 19    1800.0     30.0  0.500000      1
# 20    3000.0     50.0  0.833333      1
# 21    3600.0     60.0  1.000000      1

# %%
cal_min.hist(column='minutes',bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111950860>]], dtype=object)

# %%
cal_month= cal_df.groupby('month',as_index=False)['count'].sum()

# %%
cal_month
# Out:
#     month  count
# 0       1      7
# 1       2      4
# 2       3      8
# 3       4      2
# 4       5     15
# 5       6      5
# 6       7      2
# 7       8      1
# 8       9      2
# 9      10     16
# 10     11     24
# 11     12     10

# %%
def plot(x,y,z, xlabel, ylabel, title, fig_size, fig_color, flag):

    try:
        fig,ax= plt.subplots(nrows=1)
        ax.bar(z[0:5],y[0:5], color = fig_color)
        ax.set_title(title)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)

        if flag == '-T' or flag == '-L':
            plt.xticks(z[0:5], x[0:5])

        fig.set_size_inches(fig_size)
        return fig
    except:
        return "Can't generate plot"

# %%
months = [ "January",
          "Febuary",
          "March",
          "April",
          "May",
          "June",
          "July",
          "August",
          "September",
          "October",
          "November",
          "December"]

# %%
def plot_tweetDate(x,y,x_column, y_column,xlabel, ylabel, title, fig_size, fig_color):
    fig,ax= plt.subplots(nrows=1)
    ax.bar(x[x_column],x[y_column], color = fig_color)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.xticks(x[x_column], y)
    fig.set_size_inches(fig_size)
    return fig

# %%
plot_tweetDate(cal_month, months, 'month','count','Month', 'Number of Events ', 'Total Events Per Month', (15,5) , 'Blue')

# %%
cal_month_time = cal_df.groupby('month',as_index=False)['hours'].sum()

# %%
cal_month_time
# Out:
#     month      hours
# 0       1  11.500000
# 1       2   8.000000
# 2       3  10.750000
# 3       4   4.250000
# 4       5  37.683333
# 5       6  10.750000
# 6       7   2.500000
# 7       8   1.000000
# 8       9   1.500000
# 9      10  20.833333
# 10     11  29.750000
# 11     12  10.333333

# %%
plot_tweetDate(cal_month_time, months,'month','hours','Month', 'Hours Spent ', 'Total Time Spent Per Month', (15,5) , 'Maroon')
